# %% [markdown]
# # Task 1

# %% [markdown]
# Я ориентировался на

# %%
# !pip install -r requirements.txt

# %%
# !chmod +x ./section1/download_data.sh
# !./section1/download_data.sh

# %%
import torch
torch.__version__
# Out:
# '1.11.0+cu102'

# %%
import section1.train

# %%
section1.train.train(scaling_type="None")
# Out:
# ...
#   0%|          | 0/40 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 section1.train.train(scaling_type="None")
#
# File ~/EDL/hw3/section1/train.py:82, in train(**kwargs)
#      80 num_epochs = 5
#      81 for epoch in range(0, num_epochs):
# ---> 82     scales.append(train_epoch(train_loader, model, criterion, optimizer, device=device, **kwargs))
#      83 return scales
#
# File ~/EDL/hw3/section1/train.py:28, in train_epoch(train_loader, model, criterion, optimizer, device, scaling_type, loss_scale, up_scale, down_scale, up_scale_freq)
#      24 loss_scale_list = []
#      26 pbar = tqdm(enumerate(train_loader), total=len(train_loader))
# ---> 28 for i, (images, labels) in pbar:
#      29     images = images.to(device)
#      30     labels = labels.to(device)
#
# ...

# %%
section1.train.train(scaling_type="const")
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# torch.float32
# ...

# %%
scales = section1.train.train(scaling_type="dynamic")

# %%
import matplotlib.pyplot as plt
plt.plot(scales[0], range(len(scales[0])))

# %%
import inspect
inspect.getmro(torch.optim.Adam)

# %%
# %pip install -r requirements.txt
